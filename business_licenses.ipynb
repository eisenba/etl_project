# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ### Store CSV into a Dataframe

# %%
csv_file = "./Resources/licenses_data.csv"
licenses_data_df = pd.read_csv(csv_file)
licenses_data_df.head()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                  ID  LICENSE ID  ACCOUNT NUMBER  SITE NUMBER  \
# 0  2488875-20190116     2635860          409881            1
# 1  2641783-20181231     2641783          357055            3
# 2  1819083-20181116     2624618          316764            1
# 3  2205845-20180616     2591692          218232            3
# 4  2488830-20181116     2625726          409881            1
#
#                  LEGAL NAME DOING BUSINESS AS NAME                  ADDRESS  \
# 0  THE PISOLINO CORPORATION               PISOLINO     2755 W BELMONT AVE 1
# 1     D.C. MAD HATTER, INC.  D.C. MAD HATTER, INC.  1200 W 35TH ST 5TH 5400
# 2              DENMAX CORP.           DENMAX CORP.   2702 W CHICAGO AVE 1ST
# ...

# %% [markdown]
# ### Create new data with select columns and group

# %%
new_licenses_data_df = licenses_data_df[['LEGAL NAME','ZIP CODE', 'LICENSE DESCRIPTION', 'DATE ISSUED']].copy()
new_licenses_data_df.head()
# Out:
#                  LEGAL NAME ZIP CODE  \
# 0  THE PISOLINO CORPORATION    60618
# 1     D.C. MAD HATTER, INC.    60609
# 2              DENMAX CORP.    60622
# 3          DONNA  ARMSTRONG    60616
# 4  THE PISOLINO CORPORATION    60618
#
#                              LICENSE DESCRIPTION DATE ISSUED
# 0  Consumption on Premises - Incidental Activity    12/31/18
# 1                       Limited Business License    12/31/18
# 2                       Limited Business License    12/31/18
# 3                     Regulated Business License    12/31/18
# 4                      Retail Food Establishment    12/31/18

# %%
#groupby license type
grouped_licenses_df = new_licenses_data_df.groupby(['LICENSE DESCRIPTION', 'ZIP CODE', 'LEGAL NAME', 'DATE ISSUED'])
print(grouped_licenses_df)
grouped_licenses_df.count().head(40)
# Out:
# ...
# Empty DataFrame
# Columns: []
# ...

# %% [markdown]
# ### Connect to local database

# %%
rds_connection_string = "<postgres:huffhuff@localhost:5432/business_licenses_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %% [markdown]
# ### Check for Tables

# %% [markdown]
# ### Use pandas to load csv converted dataframe into database
